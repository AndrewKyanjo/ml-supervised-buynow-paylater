# %%
import pandas as pd

from ml_toolkit.audit import run_data_audit

# %%
from pathlib import Path

RAW_DATA_PATH = Path("../data/raw/data.csv")

df = pd.read_csv(RAW_DATA_PATH)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               10345 non-null  int64
#  1   age                   10345 non-null  int64
#  2   employment_type       10345 non-null  str
#  3   monthly_income        10345 non-null  float64
#  4   credit_score          10345 non-null  int64
#  5   purchase_amount       10345 non-null  float64
#  6   product_category      10345 non-null  str
#  7   bnpl_installments     10345 non-null  int64
#  8   repayment_delay_days  10345 non-null  int64
#  9   missed_payments       10345 non-null  int64
#  10  default_flag          10345 non-null  int64
#  11  app_usage_frequency   10345 non-null  float64
#  12  location              10345 non-null  str
#  13  transaction_date      10345 non-null  str
#  14  debt_to_income_ratio  10345 non-null  float64
# ...

# %%
audit = run_data_audit(df, target_col="default_flag", id_col="user_id")

# %%
print(audit)
# Out:
# {'schema':                         dtype  missing_count  missing_pct  n_unique  \
# user_id                 int64              0          0.0     10345
# age                     int64              0          0.0        42
# employment_type           str              0          0.0         4
# monthly_income        float64              0          0.0      9984
# credit_score            int64              0          0.0       534
# purchase_amount       float64              0          0.0      4011
# product_category          str              0          0.0         5
# bnpl_installments       int64              0          0.0         4
# repayment_delay_days    int64              0          0.0        33
# missed_payments         int64              0          0.0         8
# default_flag            int64              0          0.0         2
# app_usage_frequency   float64              0          0.0       901
# location                  str              0          0.0         6
# ...

# %%
audit["missingness"]
# Out:
# Empty DataFrame
# Columns: [feature, missing_count, percentage]
# Index: []

# %%
audit["cardinality"]
# Out:
#             feature  n_unique
# 0  transaction_date       365
# 1          location         6
# 2  product_category         5
# 3   employment_type         4
# 4  customer_segment         3

# %%
audit["duplicates"]
# Out:
# {'full_row_duplicates': 0, 'duplicate_id_rows': 0, 'conflicting_id_rows': 0}

# %%
audit["hidden_missingness"]
# Out:
# Empty DataFrame
# Columns: [feature, hidden_missing_count, percentage]
# Index: []

# %%
audit["target"]
# Out:
#    class  count  percentage
# 0      0   6305   60.947318
# 1      1   4040   39.052682

# %%
audit["id"]
# Out:
# {'total_rows': 10345,
#  'unique_ids': 10345,
#  'missing_ids': 0,
#  'duplicate_ids': 0}

# %%
audit["constant_features"]
# Out:
#                  feature  dominant_percentage  is_strictly_constant
# 0       customer_segment            73.165781                 False
# 1           default_flag            60.947318                 False
# 2        purchase_amount            58.511358                 False
# 3        missed_payments            37.090382                 False
# 4      bnpl_installments            25.587240                 False
# 5        employment_type            25.442243                 False
# 6       product_category            20.937651                 False
# 7               location            17.013050                 False
# 8           credit_score            13.272112                 False
# 9   repayment_delay_days            11.783470                 False
# 10        monthly_income             3.431609                 False
# 11                   age             2.648623                 False
# 12            risk_score             0.599323                 False
# ...

# %%
audit["numeric_profile"]
# Out:
#                         count          mean           std          min  \
# missed_payments       10345.0      1.015950      0.996726     0.000000
# debt_to_income_ratio  10345.0      0.181071      0.124887     0.000811
# monthly_income        10345.0  35053.381898  27084.517277  5000.000000
# credit_score          10345.0    448.176124    136.518332   300.000000
# default_flag          10345.0      0.390527      0.487892     0.000000
# repayment_delay_days  10345.0      8.742774      6.781849     0.000000
# bnpl_installments     10345.0      7.477525      3.362867     3.000000
# user_id               10345.0   5173.000000   2986.488601     1.000000
# age                   10345.0     38.559884     12.131789    18.000000
# app_usage_frequency   10345.0      5.524101      2.590364     1.000000
# risk_score            10345.0    198.534094     67.541384     0.000000
# purchase_amount       10345.0   3979.402721   1500.828483   100.000000
#
# ...

# %%
audit["schema"]
# Out:
#                         dtype  missing_count  missing_pct  n_unique  \
# user_id                 int64              0          0.0     10345
# age                     int64              0          0.0        42
# employment_type           str              0          0.0         4
# monthly_income        float64              0          0.0      9984
# credit_score            int64              0          0.0       534
# purchase_amount       float64              0          0.0      4011
# product_category          str              0          0.0         5
# bnpl_installments       int64              0          0.0         4
# repayment_delay_days    int64              0          0.0        33
# missed_payments         int64              0          0.0         8
# default_flag            int64              0          0.0         2
# app_usage_frequency   float64              0          0.0       901
# location                  str              0          0.0         6
# ...
